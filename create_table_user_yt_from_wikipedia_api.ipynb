# %%
# %run ./libs/endpoint_utils

# %%
# Regex aprimorado (suporta @handle, channel, user e c/)
YT_REGEX = r'youtube\.com/(?:user/|@|c/|channel/)?([^"\'/?\s>]+)'

run_enhanced_extraction(
    source_table="workspace.default.creators_scrape_wiki",
    target_table="workspace.default.users_yt",
    regex=YT_REGEX,
    output_col="user_id"
)

# %%
# %run ./libs/para_csv

# %%
export_table_to_csv(
    table_name="workspace.default.users_yt",
    volume_output_path="/Volumes/workspace/default/content_creator_volume/output_csv"
)
