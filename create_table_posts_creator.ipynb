# %%
# %run ./libs/config_utils

# %%
# 2. Executa o Auto Loader para o arquivo de Posts
run_autoloader(
    volume_path="content_creator_volume",
    source_subpath="source",
    table_name="posts_creator",        # Nome da Tabela 2
    file_pattern="posts_creator*",   # Lê APENAS o arquivo de Posts
    overwrite=True
)

# %%
# %run ./libs/para_csv

# %%
export_table_to_csv(
    table_name="workspace.default.posts_creator",
    volume_output_path="/Volumes/workspace/default/content_creator_volume/output_csv"
)
