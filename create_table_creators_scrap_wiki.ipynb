# %%
# %run /Workspace/new/content_creator/libs/config_utils

# %%
# 1. Importa as funções de configuração e processamento
# O parâmetro overwrite=True garante que a tabela seja criada com o esquema correto
run_autoloader(
    volume_path="content_creator_volume",
    source_subpath="source",
    table_name="creators_scrape_wiki", # Nome da Tabela 1
    file_pattern="wiki_pages*",     # Lê APENAS o arquivo da Wiki
    overwrite=True
)

# %%
# %run /Workspace/new/content_creator/libs/para_csv

# %%
# 3. Exporta o resultado para CSV no Volume
export_table_to_csv(
    table_name="workspace.default.creators_scrape_wiki",
    volume_output_path="/Volumes/workspace/default/content_creator_volume/output_csv"
)
